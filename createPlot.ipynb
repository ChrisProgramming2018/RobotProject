# %%
from tensorflow.python.summary.summary_iterator import summary_iterator

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
path = "/home/leiningc/projectDocumentation/experiments/walker/runs/Walker2d-v3_seed_1_agent_TD3/events.out.tfevents.1599748151.pearl6.30386.0"
path1 = "/home/leiningc/projectDocumentation/experiments/walker/runs/Walker2d-v3_seed_2_agent_TD3/events.out.tfevents.1599748151.pearl6.30387.0"
path2 = "/home/leiningc/projectDocumentation/experiments/walker/runs/Walker2d-v3_seed_3_agent_TD3/events.out.tfevents.1599748151.pearl6.30385.0"
path3 = "/home/leiningc/projectDocumentation/experiments/walker/runs/Walker2d-v3_seed_4_agent_TD3/events.out.tfevents.1599748151.pearl6.30388.0"

# %%
p1 = "/home/leiningc/projectDocumentation/experiments/walker/runs/Walker2d-v3_lr_critic_0.001_lr_actor_0.001_learn_per_step_1_update_freq_100_num_q_target_6_seed_1_agent_TD3_ad/events.out.tfevents.1599834828.pearl6.13037.0"
p2 = "/home/leiningc/projectDocumentation/experiments/walker/runs/Walker2d-v3_lr_critic_0.001_lr_actor_0.001_learn_per_step_1_update_freq_100_num_q_target_6_seed_2_agent_TD3_ad/events.out.tfevents.1599834828.pearl6.13038.0"
p3 = "/home/leiningc/projectDocumentation/experiments/walker/runs/Walker2d-v3_lr_critic_0.001_lr_actor_0.001_learn_per_step_1_update_freq_100_num_q_target_6_seed_3_agent_TD3_ad/events.out.tfevents.1599834828.pearl6.13039.0"
p4 = "/home/leiningc/projectDocumentation/experiments/walker/runs/Walker2d-v3_lr_critic_0.001_lr_actor_0.001_learn_per_step_1_update_freq_100_num_q_target_6_seed_4_agent_TD3_ad/events.out.tfevents.1599834827.pearl6.13040.0"

# %%
td_ad1 = "/home/architect/hiwi/bachelorProject/mujoco_env/vector/halfcheetah/runs/HalfCheetah-v3lr_critic_0.01lr_actor_0.001_update_freq_50_num_q_target_6_seed_1_agent_TD3_ad/events.out.tfevents.1599815632.architect.11877.0"
td_ad2 = "/home/architect/hiwi/bachelorProject/mujoco_env/vector/halfcheetah/runs/HalfCheetah-v3lr_critic_0.01lr_actor_0.001_update_freq_50_num_q_target_6_seed_2_agent_TD3_ad/events.out.tfevents.1599815632.architect.11878.0"
td_ad3 = "/home/architect/hiwi/bachelorProject/mujoco_env/vector/halfcheetah/runs/HalfCheetah-v3lr_critic_0.01lr_actor_0.001_update_freq_50_num_q_target_6_seed_3_agent_TD3_ad/events.out.tfevents.1599815632.architect.11879.0"
td_ad4 = "/home/architect/hiwi/bachelorProject/mujoco_env/vector/halfcheetah/runs/HalfCheetah-v3lr_critic_0.01lr_actor_0.001_update_freq_50_num_q_target_6_seed_4_agent_TD3_ad/events.out.tfevents.1599815632.architect.11880.0"

# %%
mean_value, min_mean, max_mean, steps = createMean(path1,path1,path2,path3,'Evaluation_reward')
# Out:
# 9
# 9
# 9
# 9

# %%
mean_value1, min_mean1, max_mean1, steps1 = createMean(p1,p2,p3,p4, 'Evaluation_reward')
# Out:
# 9
# 9
# 9
# 9

# %%
plt.plot(steps1, min_mean1, color='b')
plt.plot(steps1, max_mean1, color='b')
plt.fill_between(steps1, min_mean1, max_mean1)
plt.plot(steps1, mean_value1,color='r')
plt.savefig("TD3.png")

# %%
len(steps)
steps = steps[:82]

# %%
plt.plot(steps, min_mean, color='y')
plt.plot(steps, max_mean, color='y')
plt.fill_between(steps, min_mean, max_mean, color='y')
plt.plot(steps, mean_value,color='k')

# %%
fig, ax = plt.subplots()
fig = plt.figure(figsize=(100,50))
ax.plot(steps1, min_mean1, color='b')
ax.plot(steps1, max_mean1, color='b')
ax.fill_between(steps1, min_mean1, max_mean1)
ax.plot(steps1, mean_value1,color='r', label= "TD3")
ax.plot(steps, min_mean, color='y')
ax.plot(steps, max_mean, color='y')
ax.fill_between(steps, min_mean, max_mean, color='y',label="own version")
ax.plot(steps, mean_value,color='k')
ax.legend(loc='upper left', frameon=False)
ax.set_xlabel("steps")
#ax.set_ylabel(" average reward over last 100 Episodes")
ax.set_ylabel("Evaluate Rewards")
ax.text(0.5,-0.3, "", size=12, ha="center", 
         transform=ax.transAxes)
plt.savefig("Walker-v3-eval.png")

# %%
mean_value, min_mean, max_mean = createMean(p2,p2,p3,p4)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-21-4d09319f1e70> in <module>
# ----> 1 mean_value, min_mean, max_mean = createMean(p2,p2,p3,p4)
#
# <ipython-input-16-4010a57d302f> in createMean(path, path1, path2, path3, name)
#       2     value = []
#       3     steps = []
# ----> 4     for e in summary_iterator(path):
#       5         for v in e.summary.value:
#       6             if v.tag == name:
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/summary/summary_iterator.py in summary_iterator(path)
#      66   """
#      67   # pylint: enable=line-too-long
# ---> 68   for r in tf_record.tf_record_iterator(path):
#      69     yield event_pb2.Event.FromString(r)
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/lib/io/tf_record.py in tf_record_iterator(path, options)
#     172   with errors.raise_exception_on_not_ok_status() as status:
#     173     reader = pywrap_tensorflow.PyRecordReader_New(
# --> 174         compat.as_bytes(path), 0, compat.as_bytes(compression_type), status)
#     175
#     176   if reader is None:
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     526             None, None,
#     527             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 528             c_api.TF_GetCode(self.status.status))
#     529     # Delete the underlying status object from memory otherwise it stays alive
#     530     # as there is a reference to status from this from the traceback due to
#
# NotFoundError: /home/architect/hiwi/bachelorProject/mujoco_env/vector/halfcheetah/runs/HalfCheetah-v3lr_critic_0.05lr_actor_0.005_update_freq_50_num_q_target_6_seed_2_agent_TD3_ad/events.out.tfevents.1599735305.architect.29334.0; No such file or directory

# %%
def createMean(path, path1, path2, path3, name="Reward"):
    value = []
    steps = []
    try:
        for e in summary_iterator(path):  
            for v in e.summary.value:
                if v.tag == name:
                    value.append(v.simple_value)
                    steps.append(e.step)
    except:
        print("error1")
    
    try:
        value1 = []
        steps1 = []
        for e in summary_iterator(path1):
            for v in e.summary.value:
                if v.tag == name:
                    value1.append(v.simple_value)
                    steps1.append(e.step)
    except:
        print("error2")
    try:
        value2 = []
        steps2 = []
        for e in summary_iterator(path2):
            for v in e.summary.value:
                if v.tag == name:
                    value2.append(v.simple_value)
                    steps2.append(e.step)
    except:
        print("error3")
    
    try:
        
        value3 = []
        steps3 = []
        for e in summary_iterator(path3):

            for v in e.summary.value:
                if v.tag == name:
                    value3.append(v.simple_value)
                    steps3.append(e.step)
    except:
        print("error4")
    valuel = len(value)
    value1l = len(value1)
    value2l = len(value2)
    value3l = len(value3)
    min_lentgh = min(valuel,value1l,value2l,value3l)
    value = value[:min_lentgh]
    value1 = value1[:min_lentgh]
    value2 = value2[:min_lentgh]
    value3 = value3[:min_lentgh]
    steps = steps[:min_lentgh]
    print(len(value))
    print(len(value1))
    print(len(value2))
    print(len(value3))
    assert len(value) == len(value1) == len(value2) == len(value3)
    mean_value = []
    for v1, v2, v3, v4 in zip(value, value1, value2, value3):
        mean_value.append((v1+v2+v3+v4)/4.)
    var = []
    for v1, v2, v3, v4, mean in zip(value, value1, value2, value3, mean_value):
        summe = ((v1 -mean)**2 + (v2 -mean)**2 + (v3 -mean)**2 + (v4 -mean)**2)/4.
        var.append(np.sqrt(summe))
    max_mean = []
    min_mean = []
    for v, m in zip(var, mean_value):
        max_mean.append(m+v)
        min_mean.append(m-v)
    return mean_value, min_mean, max_mean, steps

# %%
value = []
steps = []
try:
    for e in summary_iterator(path):
        for v in e.summary.value:
            print(v.tag)
            if v.tag == 'Reward':
                value.append(v.simple_value)
                steps.append(e.step)
except :
    print("error")
# Out:
# Reward
# Reward_mean_
# Reward
# Reward_mean_
# Reward
# Reward_mean_
# Reward
# Reward_mean_
# Reward
# Reward_mean_
# Reward
# Reward_mean_
# Reward
# Reward_mean_
# Reward
# Reward_mean_
# Reward
# Reward_mean_
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# Evaluation_reward
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# Reward
# Reward_mean_
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# Reward
# Reward_mean_
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# ...
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# Reward
# Reward_mean_
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss
# critic_loss
# actor_loss

# %%
assert 3==3 and 3==4
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-45-9431fe1aae53> in <module>
# ----> 1 assert 3==3 and 3==4
#
# AssertionError:

# %%
value = []
steps = []
try:
    for e in summary_iterator(td_ad1):
        for v in e.summary.value:
            if v.tag == name:
                value.append(v.simple_value)
                steps.append(e.step)
except :
    print("error")

# %%
value1 = []
steps1 = []
try:
    for e in summary_iterator(td_ad2):
        for v in e.summary.value:
            if v.tag == 'Reward':
                value1.append(v.simple_value)
                steps1.append(e.step)
except :
    print("error")
# Out:
# error

# %%
value1 = []
steps1 = []
try:
    for e in summary_iterator(td_ad2):
        for v in e.summary.value:
            if v.tag == 'Reward':
                value1.append(v.simple_value)
                steps1.append(e.step)
except :
    print("error")
# Out:
# error

# %%
len(steps1), len(value1)
# Out:
# (50, 50)

# %%
len(steps), len(value)
plt.plot(steps, value)
plt.plot(steps1, value1)
plt.plot(steps1, value1)
plt.plot(steps1, value1)

# %%
value1 = []
steps1 = []
for e in summary_iterator(path1):
    
    for v in e.summary.value:
        if v.tag == 'Reward':
            value1.append(v.simple_value)
            steps1.append(e.step)
            #print(v.simple_value)

# %%
value2 = []
steps2 = []
for e in summary_iterator(path2):
    
    for v in e.summary.value:
        if v.tag == 'Reward':
            value2.append(v.simple_value)
            steps2.append(e.step)
            #print(v.simple_value)

# %%
value3 = []
steps3 = []
for e in summary_iterator(path3):
    
    for v in e.summary.value:
        if v.tag == 'Reward':
            value3.append(v.simple_value)
            steps3.append(e.step)
            #print(v.simple_value)

# %%
steps[50], value[50]
# Out:
# (101000, 5198.2763671875)

# %%
steps1[50], value1[50]
# Out:
# (101000, 5337.12646484375)

# %%
mean_value = []
for v1, v2, v3, v4 in zip(value, value1, value2, value3):
    mean_value.append((v1+v2+v3+v4)/4.)

# %%
mean_value
# Out:
# [-275.11956787109375,
#  -332.5559425354004,
#  -260.74877548217773,
#  -220.62720108032227,
#  -261.9044609069824,
#  -509.35485076904297,
#  -509.2940673828125,
#  -195.34925270080566,
#  292.67033195495605,
#  930.0872421264648,
#  836.3318481445312,
#  1334.0718078613281,
#  1354.700294494629,
#  2114.0560607910156,
#  2123.896682739258,
#  2744.2596435546875,
#  2167.785614013672,
#  2842.3182983398438,
#  2768.5194396972656,
#  3050.8684692382812,
#  3043.494598388672,
#  3330.2664489746094,
#  3288.1796264648438,
#  3345.5305786132812,
#  3589.8628845214844,
#  2842.0709838867188,
#  2843.095916748047,
#  4273.742248535156,
#  4302.8973388671875,
#  4343.476745605469,
#  4374.689270019531,
#  4482.390930175781,
#  4563.467712402344,
#  4696.1842041015625,
#  4832.488464355469,
#  4829.44677734375,
#  4853.5220947265625,
#  4572.1514892578125,
#  5155.930419921875,
#  5181.315185546875,
#  5275.890380859375,
#  5221.3250732421875,
#  5557.9124755859375,
#  4883.4278564453125,
#  5214.734130859375,
#  4316.764801025391,
#  5625.5006103515625,
#  5665.1387939453125,
#  4574.180603027344,
#  5815.7607421875,
#  5673.782958984375,
#  5896.436767578125,
#  4981.320007324219,
#  6084.102783203125,
#  4498.203796386719,
#  6035.142578125,
#  6217.3541259765625,
#  6339.263427734375,
#  6030.0037841796875,
#  6060.28857421875,
#  6405.449462890625,
#  6310.0384521484375,
#  6408.0,
#  6606.6131591796875,
#  6547.438720703125,
#  6312.186279296875,
#  6551.953125,
#  6553.9716796875,
#  6681.1993408203125,
#  6547.948974609375,
#  6809.5672607421875,
#  6774.9263916015625,
#  6725.3564453125,
#  6942.5086669921875,
#  6912.2261962890625,
#  6907.6715087890625,
#  6807.7122802734375,
#  7045.8155517578125,
#  6854.803955078125,
#  6961.2864990234375,
#  6944.271728515625,
#  6765.84521484375,
#  7048.9754638671875,
#  7022.6026611328125,
#  7147.05224609375,
#  7216.0238037109375,
#  7272.3326416015625,
#  7277.152099609375,
#  7355.9931640625,
#  7120.537841796875,
#  7248.7366943359375,
#  7552.9129638671875,
#  7165.4678955078125,
#  7518.6473388671875,
#  6091.258850097656,
#  7346.834716796875,
#  5766.642883300781,
#  7575.7452392578125,
#  7552.341552734375,
#  7526.83349609375,
#  7710.17138671875,
#  7706.945068359375,
#  7450.7215576171875,
#  7728.6295166015625,
#  7742.9063720703125,
#  7818.5208740234375,
#  9443.41748046875,
#  9464.801025390625,
#  9445.966552734375,
#  9501.054443359375,
#  9570.58056640625,
#  9447.502197265625,
#  9411.608642578125]

# %%
plt.plot(steps, mean_value)
plt.plot(steps, value)
#plt.plot(steps, value1)
plt.plot(steps, value2)
#plt.plot(steps, value3)

# %%
var = []
for v1, v2, v3, v4, mean in zip(value, value1, value2, value3, mean_value):
    print((v1-mean)**2)
    summe = ((v1 -mean)**2 + (v2 -mean)**2 + (v3 -mean)**2 + (v4 -mean)**2)/4.
    var.append(np.sqrt(summe))
# Out:
# 957.4631601283327
# 16229.210109938882
# 33.90335245967435
# 7163.404509963948
# 2434.6479286468966
# 986.1987150088535
# 1171.8503499180079
# 883.1654434858101
# 125025.02090605849
# 102105.002804983
# 1520445.3867119588
# 10850.755903542973
# 732209.2581509035
# 100051.8021892989
# 249797.69414247037
# 23043.29188479483
# 181967.4647368947
# 299009.3168960847
# 467515.8570116097
# 267654.3443621136
# 166606.2974866936
# 332491.780174979
# 160489.8763471283
# 1495757.2163195945
# 140132.07791189197
# 259.77357015386224
# 1348963.7915103892
# 16120.799992684275
# 73386.02957727015
# 15520.150243077427
# 23203.318421635777
# 42456.19502905384
# 23234.679381553084
# 26237.474526777864
# 224769.34001461044
# 42136.18183732033
# 48675.121307745576
# 1761327.1873022467
# 10475.092714369297
# 3.2718945145606995
# 7748.512375891209
# 14166.72396697104
# 103615.8534861952
# 1433175.1955140978
# 187765.85847908258
# 1639701.1175895864
# 1446.7566855102777
# 168932.94088484347
# 1360099.3430939354
# 8315.783519983292
# 226106.5188422799
# 517.9069176316261
# 1014758.7690521814
# 29778.23770290613
# 1951015.081447456
# 171404.4903395176
# 45529.67203094065
# 14815.513534605503
# 12186.440451279283
# 97074.53829789162
# 87962.49423748255
# 21425.676361098886
# 18035.51948571205
# 1890.795323625207
# 55628.60828882456
# 133855.40463501215
# 311493.15987610817
# 187854.09846520424
# 179835.1122802645
# 6404.961898863316
# 201984.95925487578
# 30692.49931038916
# 11167.989945411682
# 519255.5284652859
# 277723.210235253
# 374444.6462381035
# 53238.63346518576
# 19903.554000392556
# 132360.06808525324
# 101944.64796818793
# 65237.21632295847
# 86031.64978122711
# 42238.32790090144
# 79190.23327054083
# 207016.11337661743
# 183217.96153487265
# 214349.8971541077
# 1986.4909935593605
# 256507.62714481354
# 145918.9639106393
# 287738.0820441395
# 123388.31113173068
# 254844.90363301337
# 321990.9963476807
# 13094646.993577573
# 232304.93691450357
# 5315821.925004873
# 56498.075060382485
# 166788.28668743372
# 233974.85393738747
# 361268.4982702732
# 344732.10670000315
# 316825.1049578339
# 239471.0447603613
# 498844.06737329066
# 108294.74226488173
# 1728334.8570145518
# 453640.2338273674
# 174862.20407634974
# 290336.6691405922
# 181456.1357975155
# 733403.0208714157
# 62035.169257223606
# 539450.441408217
# 656145.286425963
# 1473197.3596308231
# 281659.8002073765
# 214763.2284451127
# 264603.24079728127
# 2104074.5500536114
# 378312.0899736881
# 180197.14088255167
#  548.8023319583465,
#  535.1548033202032,
#  497.6275674604709,
#  531.4808875205854,
#  594.5340377844517,
#  563.6074177043558,
#  671.0741766495701,
#  641.6607365357311,
#  606.3419878964452,
#  619.6216312289071,
#  599.2275979748204,
#  673.9298656324487,
#  657.4415085758095,
#  507.877130802563,
#  557.8108246179606,
#  513.3832392052741,
#  667.1642015494576,
#  592.3693213127251,
#  711.1894312138917,
#  540.6133998995665,
#  588.4604905863926,
#  677.2100644563078,
#  766.3444973049044,
#  490.66499388704835,
#  590.402017759177,
#  595.6257664566848,
#  514.0512665061377,
#  552.5775392405333,
#  503.41550289665315,
#  718.652920647032,
#  592.7182582015105,
#  573.217337177656,
#  537.4899187566461,
#  356.2364427366054,
#  577.7924559720744,
#  478.94960800695065,
#  509.9346570486122,
#  595.7825867838235,
#  455.82556327752746,
#  703.2434725563048,
#  508.61882257091065,
#  641.4386920058685,
#  437.46581587348044,
#  606.8854886300073,
#  456.38362363640084,
#  464.25444378289836,
#  673.1820342851983,
#  513.5561113536418,
#  418.5620820036406,
#  547.18665773624,
#  532.7893615819818,
#  366.68471168391295,
#  605.0207307350914,
#  590.649528721431,
#  578.7193393088885,
#  509.56488345409724,
#  606.38842732085,
#  563.6304037228898,
#  524.8701805139677,
#  567.3004911169683,
#  498.7229804339969,
#  570.1294126427152,
#  425.7671720501223,
#  582.7107062167927,
#  609.9475330915644,
#  379.90503146004465,
#  534.6655921360654,
#  509.14285955472843,
#  604.6091242377992,
#  368.3234976270402,
#  533.388406380944,
#  344.52432513165365,
#  411.13251656339963,
#  495.34158410896026,
#  435.3608977631364,
#  636.7529620884537,
#  474.5083487343867,
#  294.216967616099,
#  466.09732963601783,
#  494.9869253904538,
#  381.6830546618535,
#  523.194406091452,
#  680.9336607607293,
#  493.3063000066846,
#  377.49880896460934,
#  379.97632783349616,
#  428.3970038339837,
#  586.9617475662037,
#  404.94343098438895,
#  539.7998758744923,
#  356.0240501202157,
#  535.3475234637589,
#  370.88167518081514]

# %%
max_mean = []
min_mean = []
for v, m in zip(var, mean_value):
    max_mean.append(m+v)
    min_mean.append(m-v)

# %%
max_mean
# Out:
# [-227.9975966581687,
#  -250.502159327436,
#  -237.22438103526702,
#  -168.1800688236143,
#  -225.0528989032676,
#  -481.3346955628278,
#  -431.6458020843095,
#  24.43573505868636,
#  603.0708576108728,
#  1239.3308311175574,
#  1556.306277245942,
#  1777.7904973300588,
#  2042.2654401740824,
#  2572.0018975653766,
#  2916.5132902204123,
#  2913.0857157194055,
#  3261.256432063521,
#  3606.7956762379445,
#  3533.596099023971,
#  4041.0382894758177,
#  3764.4278405275863,
#  4327.808624390259,
#  4556.5155933049355,
#  4198.341439864613,
#  4649.266446887622,
#  3813.5621552271014,
#  4395.779700492138,
#  4800.263458047161,
#  4788.678204075783,
#  4883.721294086826,
#  4785.787058890578,
#  4908.183493862902,
#  4880.177906075607,
#  5299.212207201627,
#  5334.389666831001,
#  5224.519733078466,
#  5358.718303066097,
#  9660.006569885767,
#  9357.866817868317,
#  9557.980265977018,
#  9482.060406253182,
#  9654.29933128928,
#  9369.637650137049,
#  9545.069742368552,
#  9478.705966651998,
#  9339.362667873325,
#  9429.439477717096,
#  9463.876440396652,
#  9684.231533928281,
#  9616.06542617026,
#  9529.691580341718,
#  9539.893239069146,
#  9174.491813830355,
#  9671.087011636137,
#  9495.398338475701,
#  9470.128016423612,
#  9756.629510611949,
#  9510.062623824402,
#  9602.368838767243,
#  9590.940844055285,
#  9714.30258360743,
#  9654.09374556098,
#  9690.978628278444,
#  9723.626543558275,
#  9742.414111751648,
#  9883.362576277386,
#  9545.438191431767,
#  9480.35700387864,
#  9573.849865744052,
#  9779.284967050731,
#  9439.296772230788,
#  9670.915506125717,
#  9706.822746494869,
#  9808.264505324514,
#  9565.26031802441,
#  9933.194335523975,
#  9827.29934903539,
#  9662.294008638968,
#  9855.111282132593,
#  9586.536945277747,
#  9895.68825053334,
#  9635.168295096997,
#  9976.703381998042,
#  9914.917259654065,
#  9679.170656460044,
#  9860.967838229815,
#  9725.471961117228,
#  9850.525872284674,
#  9621.076671455165,
#  10000.509744271569,
#  9677.251620053528,
#  9870.002389610274,
#  9823.127961062086,
#  9790.36455987251,
#  10176.72635076033,
#  9718.996385843762,
#  9517.55827620985,
#  9885.441567917267,
#  9975.68248203108,
#  9684.609812474353,
#  10073.043771325827,
#  10234.10993029198,
#  9792.18398555356,
#  9812.786650761484,
#  9819.46680634912,
#  9871.814484302733,
#  10051.762772956828,
#  9850.909983718764,
#  10040.854319233867,
#  9926.604616526465,
#  9982.849720729384,
#  9782.49031775894]

# %%
plt.plot(steps, min_mean, color='b')
plt.plot(steps, max_mean, color='b')
plt.fill_between(steps, min_mean, max_mean)
plt.plot(steps, mean_value,color='r')
plt.savefig("TD3.png")

# %%
plt.savefig("TD3.png")

# %%
mean_value, min_mean, max_mean =createMean(p1,p2,p3,p4)
# Out:
# ---------------------------------------------------------------------------
# DataLossError                             Traceback (most recent call last)
# <ipython-input-72-093808303e0a> in <module>
# ----> 1 mean_value, min_mean, max_mean =createMean(p1,p2,p3,p4)
#
# <ipython-input-70-7a32d6b52e2e> in createMean(path, path1, path2, path3, name)
#      16     value2 = []
#      17     steps2 = []
# ---> 18     for e in summary_iterator(path2):
#      19         for v in e.summary.value:
#      20             if v.tag == name:
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/summary/summary_iterator.py in summary_iterator(path)
#      66   """
#      67   # pylint: enable=line-too-long
# ---> 68   for r in tf_record.tf_record_iterator(path):
#      69     yield event_pb2.Event.FromString(r)
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/lib/io/tf_record.py in tf_record_iterator(path, options)
#     179     while True:
#     180       try:
# --> 181         reader.GetNext()
#     182       except errors.OutOfRangeError:
#     183         break
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in GetNext(self)
#     487
#     488     def GetNext(self):
# --> 489         return _pywrap_tensorflow_internal.PyRecordReader_GetNext(self)
#     490
#     491     def record(self):
#
# DataLossError: truncated record at 15800378
